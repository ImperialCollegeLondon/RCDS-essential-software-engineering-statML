# %% [markdown]
# # Writing New Code with Copilot
#
# We can use Copilot to write new pieces of code. When doing so, the following are useful tips:
#
# 1. **Provide a description**: Copilot can generate code based on the description you provide. The more detailed the description, the better the code generated.
# 2. **Be specific**: For example, when writing a function, you might specify:
#     - The types and purposes of arguments
#     - The return type
#     - The expected behavior
#     - Any constraints or requirements
#     - If and when exceptions should be raised
# 3. **Iterate**: Copilot may not get it right the first time. Describe problems and what you would like done differently. This can be done in chat, or by make iterative changes in the editor.
# 4. **Set the style**: Copilot is aware of other code in the file and can generate code that is consistent with it. Writing some code before asking Copilot to generate more can help it understand the style you are looking for.
# 5. **Be critical of suggestions**: Copilot may generate code that is not correct or not what you want. It is important to review the code and make sure it is correct and does what you want.
# 6. **Test the code**: You should always test code you write, preferably by writing formal tests in a unit-testing framework such as ```unittest``` or ```pytest``` in Python. This is doubly important when using Copilot, as the code may not be correct or may not do what you expect. Copilot can help you write tests.
# 7. **Understand the code**: Copilot cannot replace the need for you to understand the code you're writing. It is best suited to speeding up the production of tasks you could do yourself. It may be able to help you produce code one step more complicated than you could do yourself, but you should make sure you understand what is going on before you use it. This can be a good way to learn new techniques or patterns, and can be aided by asking Copilot for explanations of bits you don't understand. If you try to produce code that is substantially beyond your current abilities, you will likely make mistakes and not understand how to fix them. As a result, you should carry on developing your skills as a programmer instead of relying on Copilot (or any other AI tool) to do the work for you.
# 8. **Break down large tasks**: Copilot is better at generating small pieces of code than large ones. If you have a large task, try to break it down into smaller pieces that you can ask Copilot to generate for you. This will make it easier for Copilot to understand what you want and generate the correct code. Copilot can help you with this process by suggesting ways to break down the task.

# %% [markdown]
# ## Example
#
# In the code cell below, the tutor will demonstrate how to write a function which accepts a number of data series in a Numpy array, and produces a line plot in Matplotlib.

# %% [markdown]
# ## Exercise
#
# Set yourself the task of writing a function that you could write yourself in 30-60 minutes. See if you can get Copilot to generate the code for you. While doing this be mindful of the following questions:
# - Be mindful of what you are asking Copilot to do. What worked well? What didn't?
# - Is the code correct?
# - Is it different from what you would have written? Is it better of worse?
# - Did you learn any new programming techniques?

# %%
import torch
import gpytorch
import numpy as np
from matplotlib import pyplot as plt
from torch.optim import LBFGS

# Define the function that takes a 5D input and computes sin+cos
def target_function(x):
    """
    Takes a 5D input tensor and computes sin+cos
    x: tensor of shape (..., 5)
    returns: tensor of shape (...)
    """
    return torch.sum(torch.sin(x) + torch.cos(x), dim=-1)

# Generate training data
def generate_data(n_samples=100, n_dims=5, test=False):
    """Generate random points in the 5D space"""
    if test:
        x = torch.rand(n_samples, n_dims) * 8.0 - 4.0  # Range [-4, 4]
    else:
        x = torch.rand(n_samples, n_dims) * 6.0 - 3.0  # Range [-3, 3]
    
    y = target_function(x)
    return x, y

# Define the GP model
class GPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood):
        super(GPModel, self).__init__(train_x, train_y, likelihood)
        self.mean_module = gpytorch.means.ConstantMean()
        self.covar_module = gpytorch.kernels.ScaleKernel(
            gpytorch.kernels.RBFKernel(ard_num_dims=5)
        )
        
    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

# Train and evaluate the GP model
def train_and_evaluate_gp(n_train=100, n_test=50):
    # Generate training data
    train_x, train_y = generate_data(n_samples=n_train)
    
    # Initialize likelihood and model
    likelihood = gpytorch.likelihoods.GaussianLikelihood()
    model = GPModel(train_x, train_y, likelihood)
    
    # Set model and likelihood in training mode
    model.train()
    likelihood.train()
    
    # Use the LBFGS optimizer
    optimizer = LBFGS(model.parameters(), lr=0.001, max_iter=10000)
    
    # "Loss" for GPs - the marginal log likelihood
    mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)
    
    # Training loop
    def closure():
        optimizer.zero_grad()
        output = model(train_x)
        loss = -mll(output, train_y)
        loss.backward()
        return loss
    
    print("Training the GP model...")
    losses = []
    
    # Train for 50 iterations
    # for i in range(50):
    loss = optimizer.step(closure)
    losses.append(loss.item())
    print(f"Final loss: {loss.item()}")
    # if i % 10 == 0:
    #     print(f"Iteration {i}/{50}: Loss = {loss.item()}")
    
    print(f"Final loss: {losses[-1]}")
    
    # Generate test data
    test_x, test_y = generate_data(n_samples=n_test, test=True)
    
    # Evaluate the model
    model.eval()
    likelihood.eval()
    
    # Make predictions
    with torch.no_grad(), gpytorch.settings.fast_pred_var():
        observed_pred = likelihood(model(test_x))
        pred_mean = observed_pred.mean
    
    # Calculate RMSE
    rmse = torch.sqrt(torch.mean((pred_mean - test_y) ** 2))
    print(f"Test RMSE: {rmse.item()}")
    
    return model, rmse

# Run the training and evaluation
model, rmse = train_and_evaluate_gp(n_train=1000, n_test=100)
# Out:
# Training the GP model...
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 1.7130115032196045 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 1.5806324481964111 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 2.015166997909546 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 1.7301716804504395 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 3.3018267154693604 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 5.992680549621582 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 5.526817798614502 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 8.230655670166016 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 7.017886161804199 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 7.873005390167236 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 8.565529823303223 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 14.868368148803711 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 11.402681350708008 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 12.335529327392578 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 15.753729820251465 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 10.682890892028809 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 8.698294639587402 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 12.609756469726562 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 9.88371467590332 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 15.491369247436523 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 11.162314414978027 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 10.58485221862793 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 13.409488677978516 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 10.567069053649902 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 14.680808067321777 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 12.192477226257324 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 12.356705665588379 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 11.363040924072266 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 12.771170616149902 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 14.699566841125488 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 13.529779434204102 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 18.289329528808594 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 8.905671119689941 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 15.370355606079102 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 12.436293601989746 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 10.696213722229004 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 12.429759979248047 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 11.114909172058105 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 21.07383918762207 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 9.601166725158691 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 15.958600044250488 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 7.659870624542236 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 13.828964233398438 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 16.305904388427734 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 20.69378089904785 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 10.128254890441895 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 13.485183715820312 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 8.991005897521973 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 12.217864990234375 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 12.505664825439453 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 14.700738906860352 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 13.863205909729004 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 14.41430950164795 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 11.701516151428223 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 9.763045310974121 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 12.963329315185547 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 10.936114311218262 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 18.044757843017578 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 10.557574272155762 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 14.931615829467773 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 14.819731712341309 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 11.903939247131348 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 10.049169540405273 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 8.053080558776855 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 14.406998634338379 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 12.356725692749023 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 12.811742782592773 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 13.751443862915039 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 11.194083213806152 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 14.141295433044434 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 11.386460304260254 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 13.826181411743164 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 11.38899040222168 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 16.492820739746094 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 12.382955551147461 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 18.645858764648438 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 12.227089881896973 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 11.415085792541504 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 15.112637519836426 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 9.861298561096191 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 12.744182586669922 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 12.895617485046387 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 13.169412612915039 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 12.804482460021973 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 15.5285062789917 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 11.054570198059082 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 12.467436790466309 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 17.06597900390625 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 16.126558303833008 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 11.341348648071289 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 13.319925308227539 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 16.092073440551758 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 16.84186363220215 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 12.326862335205078 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 12.567931175231934 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 16.21869659423828 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 8.163403511047363 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 8.608229637145996 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 15.351302146911621 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 11.494126319885254 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# ...
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 12.493478775024414 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 15.413847923278809 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 12.777353286743164 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 9.677888870239258 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 12.577731132507324 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 13.04541301727295 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 14.096100807189941 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 13.378531455993652 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 12.152713775634766 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 14.791461944580078 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 10.844141006469727 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 13.861257553100586 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 12.6841459274292 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 19.929481506347656 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 11.750991821289062 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# /home/choudhury/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:338: NumericalWarning: CG terminated in 1000 iterations with average residual norm 10.671090126037598 which is larger than the tolerance of 1 specified by linear_operator.settings.cg_tolerance. If performance is affected, consider raising the maximum number of CG iterations by running code in a linear_operator.settings.max_cg_iterations(value) context.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 100
#      97     return model, rmse
#      99 # Run the training and evaluation
# --> 100 model, rmse = train_and_evaluate_gp(n_train=1000, n_test=100)
#
# Cell In[7], line 73, in train_and_evaluate_gp(n_train, n_test)
#      69 losses = []
#      71 # Train for 50 iterations
#      72 # for i in range(50):
# ---> 73 loss = optimizer.step(closure)
#      74 losses.append(loss.item())
#      75 print(f"Final loss: {loss.item()}")
#
# File ~/miniconda3/envs/post_env/lib/python3.12/site-packages/torch/optim/optimizer.py:493, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     488         else:
#     489             raise RuntimeError(
#     490                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     491             )
# --> 493 out = func(*args, **kwargs)
#     494 self._optimizer_step_code()
#     496 # call optimizer step post hooks
#
# File ~/miniconda3/envs/post_env/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/miniconda3/envs/post_env/lib/python3.12/site-packages/torch/optim/lbfgs.py:457, in LBFGS.step(self, closure)
#     452 if n_iter != max_iter:
#     453     # re-evaluate function only if not in last iteration
#     454     # the reason we do this: in a stochastic setting,
#     455     # no use to re-evaluate that function here
#     456     with torch.enable_grad():
# --> 457         loss = float(closure())
#     458     flat_grad = self._gather_flat_grad()
#     459     opt_cond = flat_grad.abs().max() <= tolerance_grad
#
# File ~/miniconda3/envs/post_env/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# Cell In[7], line 64, in train_and_evaluate_gp.<locals>.closure()
#      62 optimizer.zero_grad()
#      63 output = model(train_x)
# ---> 64 loss = -mll(output, train_y)
#      65 loss.backward()
#      66 return loss
#
# File ~/miniconda3/envs/post_env/lib/python3.12/site-packages/gpytorch/module.py:82, in Module.__call__(self, *inputs, **kwargs)
#      81 def __call__(self, *inputs, **kwargs) -> Union[Tensor, Distribution, LinearOperator]:
# ---> 82     outputs = self.forward(*inputs, **kwargs)
#      83     if isinstance(outputs, list):
#      84         return [_validate_module_outputs(output) for output in outputs]
#
# File ~/miniconda3/envs/post_env/lib/python3.12/site-packages/gpytorch/mlls/exact_marginal_log_likelihood.py:82, in ExactMarginalLogLikelihood.forward(self, function_dist, target, *params, **kwargs)
#      79     raise ValueError("NaN observation policy 'fill' is not supported by ExactMarginalLogLikelihood!")
#      81 # Get the log prob of the marginal distribution
# ---> 82 res = output.log_prob(target)
#      83 res = self._add_other_terms(res, params)
#      85 # Scale by the amount of data we have
#
# File ~/miniconda3/envs/post_env/lib/python3.12/site-packages/gpytorch/distributions/multivariate_normal.py:250, in MultivariateNormal.log_prob(self, value)
#     248 # Get log determininant and first part of quadratic form
#     249 covar = covar.evaluate_kernel()
# --> 250 inv_quad, logdet = covar.inv_quad_logdet(inv_quad_rhs=diff.unsqueeze(-1), logdet=True)
#     252 res = -0.5 * sum([inv_quad, logdet, diff.size(-1) * math.log(2 * math.pi)])
#     253 return res
#
# File ~/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/operators/_linear_operator.py:1772, in LinearOperator.inv_quad_logdet(self, inv_quad_rhs, logdet, reduce_inv_quad)
#    1769 probe_vectors, probe_vector_norms = self._probe_vectors_and_norms()
#    1771 func = InvQuadLogdet.apply
# -> 1772 inv_quad_term, pinvk_logdet = func(
#    1773     self.representation_tree(),
#    1774     precond_lt.representation_tree(),
#    1775     preconditioner,
#    1776     len(precond_args),
#    1777     (inv_quad_rhs is not None),
#    1778     probe_vectors,
#    1779     probe_vector_norms,
#    1780     *(list(args) + list(precond_args)),
#    1781 )
#    1782 logdet_term = pinvk_logdet
#    1783 logdet_term = logdet_term + logdet_p
#
# File ~/miniconda3/envs/post_env/lib/python3.12/site-packages/torch/autograd/function.py:575, in Function.apply(cls, *args, **kwargs)
#     572 if not torch._C._are_functorch_transforms_active():
#     573     # See NOTE: [functorch vjp and autograd interaction]
#     574     args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 575     return super().apply(*args, **kwargs)  # type: ignore[misc]
#     577 if not is_setup_ctx_defined:
#     578     raise RuntimeError(
#     579         "In order to use an autograd.Function with functorch transforms "
#     580         "(vmap, grad, jvp, jacrev, ...), it must override the setup_context "
#     581         "staticmethod. For more details, please see "
#     582         "https://pytorch.org/docs/main/notes/extending.func.html"
#     583     )
#
# File ~/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/functions/_inv_quad_logdet.py:132, in InvQuadLogdet.forward(ctx, representation_tree, precond_representation_tree, preconditioner, num_precond_args, inv_quad, probe_vectors, probe_vector_norms, *args)
#     130 # Perform solves (for inv_quad) and tridiagonalization (for estimating logdet)
#     131 rhs = torch.cat(rhs_list, -1)
# --> 132 solves, t_mat = linear_op._solve(rhs, preconditioner, num_tridiag=num_random_probes)
#     134 # Final values to return
#     135 logdet_term = torch.zeros(linear_op.batch_shape, dtype=ctx.dtype, device=ctx.device)
#
# File ~/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/operators/_linear_operator.py:795, in LinearOperator._solve(self, rhs, preconditioner, num_tridiag)
#     780 def _solve(
#     781     self: Float[LinearOperator, "... N N"],
#     782     rhs: Float[torch.Tensor, "... N C"],
#    (...)
#     790     ],
#     791 ]:
#     792     r"""
#     793     TODO
#     794     """
# --> 795     return utils.linear_cg(
#     796         self._matmul,
#     797         rhs,
#     798         n_tridiag=num_tridiag,
#     799         max_iter=settings.max_cg_iterations.value(),
#     800         max_tridiag_iter=settings.max_lanczos_quadrature_iterations.value(),
#     801         preconditioner=preconditioner,
#     802     )
#
# File ~/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/utils/linear_cg.py:248, in linear_cg(matmul_closure, rhs, n_tridiag, tolerance, eps, stop_updating_after, max_iter, max_tridiag_iter, initial_guess, preconditioner)
#     244 # Start the iteration
#     245 for k in range(n_iter):
#     246     # Get next alpha
#     247     # alpha_{k} = (residual_{k-1}^T precon_residual{k-1}) / (p_vec_{k-1}^T mat p_vec_{k-1})
# --> 248     mvms = matmul_closure(curr_conjugate_vec)
#     249     if precond:
#     250         torch.mul(curr_conjugate_vec, mvms, out=mul_storage)
#
# File ~/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/operators/added_diag_linear_operator.py:77, in AddedDiagLinearOperator._matmul(self, rhs)
#      73 def _matmul(
#      74     self: Float[LinearOperator, "*batch M N"],
#      75     rhs: Union[Float[torch.Tensor, "*batch2 N C"], Float[torch.Tensor, "*batch2 N"]],
#      76 ) -> Union[Float[torch.Tensor, "... M C"], Float[torch.Tensor, "... M"]]:
# ---> 77     return torch.addcmul(self._linear_op._matmul(rhs), self._diag_tensor._diag.unsqueeze(-1), rhs)
#
# File ~/miniconda3/envs/post_env/lib/python3.12/site-packages/linear_operator/operators/dense_linear_operator.py:65, in DenseLinearOperator._matmul(self, rhs)
#      61 def _matmul(
#      62     self: Float[LinearOperator, "*batch M N"],
#      63     rhs: Union[Float[torch.Tensor, "*batch2 N C"], Float[torch.Tensor, "*batch2 N"]],
#      64 ) -> Union[Float[torch.Tensor, "... M C"], Float[torch.Tensor, "... M"]]:
# ---> 65     return torch.matmul(self.tensor, rhs)
#
# KeyboardInterrupt:
